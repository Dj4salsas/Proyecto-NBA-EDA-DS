# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
all_games_stats=pd.read_csv(r'C:\Users\broken\Desktop\BootCamp Data Science\Proyecto EDA\Proyecto-NBA-EDA-DS\data\allgames_stats.csv')
all_games_stats
# Out:
#        G        Date   Tm    X  Opp Result  GS     MP    FG   FGA  ...  TRB  \
# 0      1  1996-11-03  LAL  NaN  MIN      W   0   6:00   0.0   1.0  ...    1
# 1      2  1996-11-05  LAL    @  NYK      W   0   3:00   0.0   1.0  ...    0
# 2      3  1996-11-06  LAL    @  CHH      L   0   7:00   2.0   3.0  ...    0
# 3      4  1996-11-08  LAL    @  TOR      L   0  17:00   3.0   8.0  ...    3
# 4      5  1996-11-10  LAL  NaN  ATL      W   0   8:00   0.0   3.0  ...    3
# ...   ..         ...  ...  ...  ...    ...  ..    ...   ...   ...  ...  ...
# 4249  17  1998-06-05  CHI    @  UTA      W   1  40:00  14.0  33.0  ...    5
# 4250  18  1998-06-07  CHI  NaN  UTA      W   1  32:00   7.0  14.0  ...    3
# 4251  19  1998-06-10  CHI  NaN  UTA      W   1  43:00  12.0  27.0  ...    8
# 4252  20  1998-06-12  CHI  NaN  UTA      L   1  45:00   9.0  26.0  ...    4
# 4253  21  1998-06-14  CHI    @  UTA      W   1  44:00  15.0  35.0  ...    1
#
#       AST  STL  BLK  TOV  PF   PTS  GmSc          Player          RSorPO
# 0       0  0.0  1.0    1   1   0.0  -1.1     Kobe Bryant  Regular Season
# 1       0  0.0  0.0    1   0   1.0  -1.1     Kobe Bryant  Regular Season
# 2       0  0.0  0.0    3   0   5.0   0.7     Kobe Bryant  Regular Season
# 3       0  0.0  1.0    0   3  10.0   5.2     Kobe Bryant  Regular Season
# 4       1  0.0  0.0    0   0   2.0   1.9     Kobe Bryant  Regular Season
# ...   ...  ...  ...  ...  ..   ...   ...             ...             ...
# 4249    3  1.0  1.0    0   2  37.0  24.8  Michael Jordan        Playoffs
# 4250    2  1.0  1.0    2   1  24.0  18.6  Michael Jordan        Playoffs
# 4251    2  2.0  0.0    3   1  34.0  21.5  Michael Jordan        Playoffs
# 4252    4  3.0  0.0    4   4  28.0  14.8  Michael Jordan        Playoffs
# 4253    1  4.0  0.0    1   2  45.0  28.5  Michael Jordan        Playoffs
#
# [4254 rows x 29 columns]

# %%
print("DataFrame shape: ",all_games_stats.shape)
print("DataFrame info: ",all_games_stats.info())
print("DataFrame columns: ",all_games_stats.columns)
print("how many missing in every column: ",all_games_stats.isna().sum())
print("type of each column: ",all_games_stats.dtypes)
print("numerical column stat: ", all_games_stats.describe().T)
# Out:
# DataFrame shape:  (4254, 29)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4254 entries, 0 to 4253
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   G       4254 non-null   int64
#  1   Date    4254 non-null   object
#  2   Tm      4254 non-null   object
#  3   X       2117 non-null   object
#  4   Opp     4254 non-null   object
#  5   Result  4254 non-null   object
#  6   GS      4254 non-null   int64
#  7   MP      4254 non-null   object
#  8   FG      4250 non-null   float64
#  9   FGA     4247 non-null   float64
#  10  FG%     4237 non-null   float64
#  11  3P      4254 non-null   int64
#  12  3PA     4254 non-null   int64
#  13  3P%     3750 non-null   float64
#  14  FT      4253 non-null   float64
#  15  FTA     4252 non-null   float64
#  16  FT%     4119 non-null   float64
#  17  ORB     4253 non-null   float64
#  18  DRB     4252 non-null   float64
#  19  TRB     4254 non-null   int64
#  20  AST     4254 non-null   int64
#  21  STL     4243 non-null   float64
#  22  BLK     4253 non-null   float64
#  23  TOV     4254 non-null   int64
#  24  PF      4254 non-null   int64
#  25  PTS     4245 non-null   float64
#  26  GmSc    4035 non-null   float64
#  27  Player  4254 non-null   object
#  28  RSorPO  4254 non-null   object
# dtypes: float64(13), int64(8), object(8)
# memory usage: 963.9+ KB
# DataFrame info:  None
# DataFrame columns:  Index(['G', 'Date', 'Tm', 'X', 'Opp', 'Result', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST',
#        'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', 'Player', 'RSorPO'],
#       dtype='object')
# how many missing in every column:  G            0
# Date         0
# Tm           0
# X         2137
# Opp          0
# Result       0
# GS           0
# MP           0
# FG           4
# FGA          7
# FG%         17
# 3P           0
# 3PA          0
# 3P%        504
# FT           1
# FTA          2
# FT%        135
# ORB          1
# DRB          2
# TRB          0
# AST          0
# STL         11
# BLK          1
# TOV          0
# PF           0
# PTS          9
# GmSc       219
# Player       0
# RSorPO       0
# dtype: int64
# type of each column:  G           int64
# Date       object
# Tm         object
# X          object
# Opp        object
# Result     object
# GS          int64
# MP         object
# FG        float64
# FGA       float64
# FG%       float64
# 3P          int64
# 3PA         int64
# 3P%       float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB         int64
# AST         int64
# STL       float64
# BLK       float64
# TOV         int64
# PF          int64
# PTS       float64
# GmSc      float64
# Player     object
# RSorPO     object
# dtype: object
# numerical column stat:         count       mean        std  min    25%    50%    75%   max
# G     4254.0  33.771039  23.250115  1.0  13.00  31.00  53.00  82.0
# GS    4254.0   0.952515   0.212698  0.0   1.00   1.00   1.00   1.0
# FG    4250.0   9.956000   3.801338  0.0   7.00  10.00  12.00  28.0
# FGA   4247.0  20.701907   6.387853  0.0  17.00  21.00  25.00  50.0
# FG%   4237.0   0.478806   0.121048  0.0   0.40   0.48   0.56   1.0
# 3P    4254.0   1.162435   1.371055  0.0   0.00   1.00   2.00  12.0
# 3PA   4254.0   3.478138   2.670980  0.0   1.00   3.00   5.00  21.0
# 3P%   3750.0   0.298587   0.276708  0.0   0.00   0.29   0.50   1.0
# FT    4253.0   6.402304   3.894380  0.0   4.00   6.00   9.00  24.0
# FTA   4252.0   7.998589   4.524951  0.0   5.00   8.00  11.00  28.0
# FT%   4119.0   0.794695   0.180556  0.0   0.69   0.82   0.93   1.0
# ORB   4253.0   1.293910   1.277438  0.0   0.00   1.00   2.00   9.0
# DRB   4252.0   5.044450   2.742909  0.0   3.00   5.00   7.00  17.0
# TRB   4254.0   6.345087   3.127640  0.0   4.00   6.00   8.00  19.0
# AST   4254.0   5.724024   3.019336  0.0   4.00   5.00   8.00  19.0
# STL   4243.0   1.745934   1.402170  0.0   1.00   2.00   3.00   7.0
# BLK   4253.0   0.701152   0.916192  0.0   0.00   0.00   1.00   5.0
# TOV   4254.0   3.092619   1.859863  0.0   2.00   3.00   4.00  11.0
# PF    4254.0   2.377292   1.412670  0.0   1.00   2.00   3.00   6.0
# PTS   4245.0  27.444287   9.671222  0.0  21.00  27.00  34.00  81.0
# GmSc  4035.0  20.548178   8.789507 -5.9  14.60  20.90  26.40  63.5

# %%
jordan = all_games_stats.loc[all_games_stats['Player'] == 'Michael Jordan']
jordan
# Out:
#        G        Date   Tm    X  Opp Result  GS     MP    FG   FGA  ...  TRB  \
# 3003   1  1984-10-26  CHI  NaN  WSB      W   1  40:00   5.0  16.0  ...    6
# 3004   2  1984-10-27  CHI    @  MIL      L   1  34:00   8.0  13.0  ...    5
# 3005   3  1984-10-29  CHI  NaN  MIL      W   1  34:00  13.0  24.0  ...    4
# 3006   4  1984-10-30  CHI    @  KCK      W   1  36:00   8.0  21.0  ...    4
# 3007   5  1984-11-01  CHI    @  DEN      L   1  33:00   7.0  15.0  ...    5
# ...   ..         ...  ...  ...  ...    ...  ..    ...   ...   ...  ...  ...
# 4249  17  1998-06-05  CHI    @  UTA      W   1  40:00  14.0  33.0  ...    5
# 4250  18  1998-06-07  CHI  NaN  UTA      W   1  32:00   7.0  14.0  ...    3
# 4251  19  1998-06-10  CHI  NaN  UTA      W   1  43:00  12.0  27.0  ...    8
# 4252  20  1998-06-12  CHI  NaN  UTA      L   1  45:00   9.0  26.0  ...    4
# 4253  21  1998-06-14  CHI    @  UTA      W   1  44:00  15.0  35.0  ...    1
#
#       AST  STL  BLK  TOV  PF   PTS  GmSc          Player          RSorPO
# 3003    7  2.0  4.0    5   2  16.0  12.5  Michael Jordan  Regular Season
# 3004    5  2.0  1.0    3   4  21.0  19.4  Michael Jordan  Regular Season
# 3005    5  6.0  2.0    3   4  37.0  32.9  Michael Jordan  Regular Season
# 3006    5  3.0  1.0    6   5  25.0  14.7  Michael Jordan  Regular Season
# 3007    5  1.0  1.0    2   4  17.0  13.2  Michael Jordan  Regular Season
# ...   ...  ...  ...  ...  ..   ...   ...             ...             ...
# 4249    3  1.0  1.0    0   2  37.0  24.8  Michael Jordan        Playoffs
# 4250    2  1.0  1.0    2   1  24.0  18.6  Michael Jordan        Playoffs
# 4251    2  2.0  0.0    3   1  34.0  21.5  Michael Jordan        Playoffs
# 4252    4  3.0  0.0    4   4  28.0  14.8  Michael Jordan        Playoffs
# 4253    1  4.0  0.0    1   2  45.0  28.5  Michael Jordan        Playoffs
#
# [1251 rows x 29 columns]

# %%
print(f"nMin: {jordan['PTS'].min()} \nMax: {jordan['PTS'].max()} \nAvg: {round(jordan['PTS'].mean())}")
# Out:
# nMin: 2.0
# Max: 61.0
# Avg: 30

# %%
print(f"nMin: {jordan['AST'].min()} \nMax: {jordan['AST'].max()} \nAvg: {round(jordan['AST'].mean())}")
# Out:
# nMin: 0
# Max: 17
# Avg: 5

# %%
print(f"nMin: {jordan['TRB'].min()} \nMax: {jordan['TRB'].max()} \nAvg: {round(jordan['TRB'].mean())}")
# Out:
# nMin: 0
# Max: 19
# Avg: 6

# %%
print(f"nMin: {jordan['FG'].min()} \nMax: {jordan['FG'].max()} \nAvg: {round(jordan['FG'].mean())}")
# Out:
# nMin: 1.0
# Max: 23.0
# Avg: 11

# %%
a4_dims = (12, 10)
fig, ax = plt.subplots(figsize= a4_dims)

jordan['Date'] = pd.to_datetime(jordan['Date'])
sns.boxplot(jordan['Date'].dt.year, jordan['PTS'], color='red').set_title('Jordan')
# Out:
# <ipython-input-28-a92f2e71320d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jordan['Date'] = pd.to_datetime(jordan['Date'])
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Jordan')

# %%
fig = plt.figure(constrained_layout=True, figsize=[11, 8])
ax = fig.add_subplot()

opponents = jordan["Opp"].unique()
wins, loses = list(), list()
for opponent in opponents:
    mapped = jordan[jordan["Opp"] == opponent]["Result"].map({"W":1, "L":0})
    wins.append(mapped.sum())
    loses.append(len(mapped) - mapped.sum())

widths = np.array(wins) - np.array(loses)
colors = ["red" if width < 0 else "green" for width in widths]

ax.hlines(y=opponents, xmin=0, xmax=widths, color=colors , alpha=0.8)
ax.hlines(y=opponents, xmin=-20, xmax=np.minimum(widths, 0)-0.5, alpha=0.2, linestyles="--")
ax.vlines(x=0, ymin=-1, ymax=len(opponents), alpha=0.3, linestyles="--")
ax.scatter(y=opponents, x=widths, color=colors)

for i in range(len(opponents)):
    ax.text(y=opponents[i], x=widths[i] + (1 if widths[i] > 0 else -1), s=widths[i], fontsize=12, color=colors[i], horizontalalignment="center", verticalalignment="center")

ax.set_title('Jordan - Games')
ax.set_yticklabels(opponents, fontsize=13)

plt.show()
# Out:
# <ipython-input-29-f979f5c4782e>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(opponents, fontsize=13)

# %%
jordan_away=jordan.loc[jordan['X']=='@']
jordan_away
# Out:
#        G       Date   Tm  X  Opp Result  GS     MP    FG   FGA  ...  TRB  AST  \
# 3004   2 1984-10-27  CHI  @  MIL      L   1  34:00   8.0  13.0  ...    5    5
# 3006   4 1984-10-30  CHI  @  KCK      W   1  36:00   8.0  21.0  ...    4    5
# 3007   5 1984-11-01  CHI  @  DEN      L   1  33:00   7.0  15.0  ...    5    5
# 3008   6 1984-11-07  CHI  @  DET      W   1  27:00   9.0  19.0  ...    4    3
# 3009   7 1984-11-08  CHI  @  NYK      W   1  33:00  15.0  22.0  ...    8    5
# ...   ..        ...  ... ..  ...    ...  ..    ...   ...   ...  ...  ...  ...
# 4244  12 1998-05-25  CHI  @  IND      L   1  41:00  12.0  27.0  ...    5    2
# 4246  14 1998-05-29  CHI  @  IND      L   1  42:00  12.0  23.0  ...    5    2
# 4248  16 1998-06-03  CHI  @  UTA      L   1  46:00  13.0  29.0  ...    3    2
# 4249  17 1998-06-05  CHI  @  UTA      W   1  40:00  14.0  33.0  ...    5    3
# 4253  21 1998-06-14  CHI  @  UTA      W   1  44:00  15.0  35.0  ...    1    1
#
#       STL  BLK  TOV  PF   PTS  GmSc          Player          RSorPO
# 3004  2.0  1.0    3   4  21.0  19.4  Michael Jordan  Regular Season
# 3006  3.0  1.0    6   5  25.0  14.7  Michael Jordan  Regular Season
# 3007  1.0  1.0    2   4  17.0  13.2  Michael Jordan  Regular Season
# 3008  3.0  1.0    5   5  25.0  14.9  Michael Jordan  Regular Season
# 3009  3.0  2.0    5   2  33.0  29.3  Michael Jordan  Regular Season
# ...   ...  ...  ...  ..   ...   ...             ...             ...
# 4244  0.0  2.0    6   4  28.0   NaN  Michael Jordan        Playoffs
# 4246  1.0  0.0    3   4  35.0   NaN  Michael Jordan        Playoffs
# 4248  0.0  2.0    0   3  33.0   NaN  Michael Jordan        Playoffs
# 4249  1.0  1.0    0   2  37.0  24.8  Michael Jordan        Playoffs
# 4253  4.0  0.0    1   2  45.0  28.5  Michael Jordan        Playoffs
#
# [621 rows x 29 columns]

# %%
a4_dims = (12, 10)
fig, ax = plt.subplots(figsize=a4_dims)

jordan_away['Date'] = pd.to_datetime(jordan_away['Date'])
sns.boxplot(jordan_away['Date'].dt.year, jordan_away['PTS'], color='red').set_title('Jordan - Away')
# Out:
# <ipython-input-31-670cac7501ce>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jordan_away['Date'] = pd.to_datetime(jordan_away['Date'])
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Jordan - Away')

# %%
fig = plt.figure(constrained_layout=True, figsize=[11, 8])
ax = fig.add_subplot()

opponents = jordan_away["Opp"].unique()
wins, loses = list(), list()
for opponent in opponents:
    mapped = jordan_away[jordan_away["Opp"] == opponent]["Result"].map({"W":1, "L":0})
    wins.append(mapped.sum())
    loses.append(len(mapped) - mapped.sum())

widths = np.array(wins) - np.array(loses)
colors = ["red" if width < 0 else "green" for width in widths]

ax.hlines(y=opponents, xmin=0, xmax=widths, color=colors , alpha=0.8)
ax.hlines(y=opponents, xmin=-20, xmax=np.minimum(widths, 0)-0.5, alpha=0.2, linestyles="--")
ax.vlines(x=0, ymin=-1, ymax=len(opponents), alpha=0.3, linestyles="--")
ax.scatter(y=opponents, x=widths, color=colors)

for i in range(len(opponents)):
    ax.text(y=opponents[i], x=widths[i] + (1 if widths[i] > 0 else -1), s=widths[i], fontsize=12, color=colors[i], horizontalalignment="center", verticalalignment="center")
ax.set_title('Jordan - Away')
ax.set_yticklabels(opponents, fontsize=13)

plt.show()
# Out:
# <ipython-input-32-7745d498fb1d>:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(opponents, fontsize=13)

# %%
jordan_home=jordan.loc[jordan['X']!='@']
jordan_home
# Out:
#        G       Date   Tm    X  Opp Result  GS     MP    FG   FGA  ...  TRB  \
# 3003   1 1984-10-26  CHI  NaN  WSB      W   1  40:00   5.0  16.0  ...    6
# 3005   3 1984-10-29  CHI  NaN  MIL      W   1  34:00  13.0  24.0  ...    4
# 3011   9 1984-11-13  CHI  NaN  SAS      W   1  43:00  18.0  27.0  ...   10
# 3012  10 1984-11-15  CHI  NaN  BOS      L   1  33:00  12.0  24.0  ...    2
# 3013  11 1984-11-17  CHI  NaN  PHI      L   1  44:00   4.0  17.0  ...    5
# ...   ..        ...  ...  ...  ...    ...  ..    ...   ...   ...  ...  ...
# 4245  13 1998-05-27  CHI  NaN  IND      W   1  36:00  12.0  20.0  ...    7
# 4247  15 1998-05-31  CHI  NaN  IND      W   1  42:00   9.0  25.0  ...    9
# 4250  18 1998-06-07  CHI  NaN  UTA      W   1  32:00   7.0  14.0  ...    3
# 4251  19 1998-06-10  CHI  NaN  UTA      W   1  43:00  12.0  27.0  ...    8
# 4252  20 1998-06-12  CHI  NaN  UTA      L   1  45:00   9.0  26.0  ...    4
#
#       AST  STL  BLK  TOV  PF   PTS  GmSc          Player          RSorPO
# 3003    7  2.0  4.0    5   2  16.0  12.5  Michael Jordan  Regular Season
# 3005    5  6.0  2.0    3   4  37.0  32.9  Michael Jordan  Regular Season
# 3011    4  3.0  2.0    4   4  45.0   NaN  Michael Jordan  Regular Season
# 3012    2  2.0  1.0    1   4  27.0  17.1  Michael Jordan  Regular Season
# 3013    7  5.0  2.0    4   5  16.0  12.5  Michael Jordan  Regular Season
# ...   ...  ...  ...  ...  ..   ...   ...             ...             ...
# 4245    4  1.0  1.0    0   2  29.0  25.6  Michael Jordan        Playoffs
# 4247    8  0.0  0.0    2   3  28.0  19.2  Michael Jordan        Playoffs
# 4250    2  1.0  1.0    2   1  24.0  18.6  Michael Jordan        Playoffs
# 4251    2  2.0  0.0    3   1  34.0  21.5  Michael Jordan        Playoffs
# 4252    4  3.0  0.0    4   4  28.0  14.8  Michael Jordan        Playoffs
#
# [630 rows x 29 columns]

# %%
a4_dims = (12, 10)
fig, ax = plt.subplots(figsize=a4_dims)

jordan_home['Date'] = pd.to_datetime(jordan_home['Date'])
sns.boxplot(jordan_home['Date'].dt.year, jordan_home['PTS'], color='red').set_title('Jordan - Home')
# Out:
# <ipython-input-34-a2c8b866354f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jordan_home['Date'] = pd.to_datetime(jordan_home['Date'])
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Jordan - Home')

# %%
fig = plt.figure(constrained_layout=True, figsize=[11, 8])
ax = fig.add_subplot()

opponents = jordan_home["Opp"].unique()
wins, loses = list(), list()
for opponent in opponents:
    mapped = jordan_home[jordan_home["Opp"] == opponent]["Result"].map({"W":1, "L":0})
    wins.append(mapped.sum())
    loses.append(len(mapped) - mapped.sum())

widths = np.array(wins) - np.array(loses)
colors = ["red" if width < 0 else "green" for width in widths]

ax.hlines(y=opponents, xmin=0, xmax=widths, color=colors , alpha=0.8)
ax.hlines(y=opponents, xmin=-20, xmax=np.minimum(widths, 0)-0.5, alpha=0.2, linestyles="--")
ax.vlines(x=0, ymin=-1, ymax=len(opponents), alpha=0.3, linestyles="--")
ax.scatter(y=opponents, x=widths, color=colors)

for i in range(len(opponents)):
    ax.text(y=opponents[i], x=widths[i] + (1 if widths[i] > 0 else -1), s=widths[i], fontsize=12, color=colors[i], horizontalalignment="center", verticalalignment="center")

ax.set_title('Jordan - Home')
ax.set_yticklabels(opponents, fontsize=13)

plt.show()
# Out:
# <ipython-input-35-7ca66ca01839>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(opponents, fontsize=13)

# %%
kobe = all_games_stats.loc[all_games_stats['Player'] == 'Kobe Bryant']
kobe
# Out:
#        G        Date   Tm    X  Opp Result  GS     MP    FG   FGA  ...  TRB  \
# 0      1  1996-11-03  LAL  NaN  MIN      W   0   6:00   0.0   1.0  ...    1
# 1      2  1996-11-05  LAL    @  NYK      W   0   3:00   0.0   1.0  ...    0
# 2      3  1996-11-06  LAL    @  CHH      L   0   7:00   2.0   3.0  ...    0
# 3      4  1996-11-08  LAL    @  TOR      L   0  17:00   3.0   8.0  ...    3
# 4      5  1996-11-10  LAL  NaN  ATL      W   0   8:00   0.0   3.0  ...    3
# ...   ..         ...  ...  ...  ...    ...  ..    ...   ...   ...  ...  ...
# 1561   8  2012-05-14  LAL    @  OKC      L   1  31:55   7.0  18.0  ...    3
# 1562   9  2012-05-16  LAL    @  OKC      L   1  42:46   9.0  25.0  ...    3
# 1563  10  2012-05-18  LAL  NaN  OKC      W   1  38:58   9.0  25.0  ...    7
# 1564  11  2012-05-19  LAL  NaN  OKC      L   1  39:46  12.0  28.0  ...    8
# 1565  12  2012-05-21  LAL    @  OKC      L   1  40:34  18.0  33.0  ...    5
#
#       AST  STL  BLK  TOV  PF   PTS  GmSc       Player          RSorPO
# 0       0  0.0  1.0    1   1   0.0  -1.1  Kobe Bryant  Regular Season
# 1       0  0.0  0.0    1   0   1.0  -1.1  Kobe Bryant  Regular Season
# 2       0  0.0  0.0    3   0   5.0   0.7  Kobe Bryant  Regular Season
# 3       0  0.0  1.0    0   3  10.0   5.2  Kobe Bryant  Regular Season
# 4       1  0.0  0.0    0   0   2.0   1.9  Kobe Bryant  Regular Season
# ...   ...  ...  ...  ...  ..   ...   ...          ...             ...
# 1561    2  0.0  0.0    3   3  20.0   7.5  Kobe Bryant        Playoffs
# 1562    4  4.0  0.0    2   4  20.0  10.6  Kobe Bryant        Playoffs
# 1563    6  2.0  0.0    2   4  36.0  27.6  Kobe Bryant        Playoffs
# 1564    5  0.0  0.0    2   1  38.0  26.7  Kobe Bryant        Playoffs
# 1565    0  2.0  0.0    2   3  42.0  25.6  Kobe Bryant        Playoffs
#
# [1566 rows x 29 columns]

# %%
print(f"nMin: {kobe['PTS'].min()} \nMax: {kobe['PTS'].max()} \nAvg: {round(kobe['PTS'].mean())}")
# Out:
# nMin: 0.0
# Max: 81.0
# Avg: 25

# %%
print(f"nMin: {kobe['AST'].min()} \nMax: {kobe['AST'].max()} \nAvg: {round(kobe['AST'].mean())}")
# Out:
# nMin: 0
# Max: 17
# Avg: 5

# %%
print(f"nMin: {kobe['TRB'].min()} \nMax: {kobe['TRB'].max()} \nAvg: {round(kobe['TRB'].mean())}")
# Out:
# nMin: 0
# Max: 16
# Avg: 5

# %%
print(f"nMin: {kobe['FG'].min()} \nMax: {kobe['FG'].max()} \nAvg: {round(kobe['FG'].mean())}")
# Out:
# nMin: 0.0
# Max: 28.0
# Avg: 9

# %%
a4_dims = (12, 10)
fig, ax = plt.subplots(figsize= a4_dims)

kobe['Date'] = pd.to_datetime(kobe['Date'])
sns.boxplot(kobe['Date'].dt.year, kobe['PTS'], color='green').set_title('Kobe')
# Out:
# <ipython-input-41-26114e9e50bb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kobe['Date'] = pd.to_datetime(kobe['Date'])
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Kobe')

# %%
fig = plt.figure(constrained_layout=True, figsize=[11, 8])
ax = fig.add_subplot()

opponents = kobe["Opp"].unique()
wins, loses = list(), list()
for opponent in opponents:
    mapped = kobe[kobe["Opp"] == opponent]["Result"].map({"W":1, "L":0})
    wins.append(mapped.sum())
    loses.append(len(mapped) - mapped.sum())

widths = np.array(wins) - np.array(loses)
colors = ["red" if width < 0 else "green" for width in widths]

ax.hlines(y=opponents, xmin=0, xmax=widths, color=colors , alpha=0.8)
ax.hlines(y=opponents, xmin=-20, xmax=np.minimum(widths, 0)-0.5, alpha=0.2, linestyles="--")
ax.vlines(x=0, ymin=-1, ymax=len(opponents), alpha=0.3, linestyles="--")
ax.scatter(y=opponents, x=widths, color=colors)

for i in range(len(opponents)):
    ax.text(y=opponents[i], x=widths[i] + (1 if widths[i] > 0 else -1), s=widths[i], fontsize=12, color=colors[i], horizontalalignment="center", verticalalignment="center")

ax.set_title('Kobe - Games')
ax.set_yticklabels(opponents, fontsize=13)

plt.show()
# Out:
# <ipython-input-42-e2a1fc59ada5>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(opponents, fontsize=13)

# %%
kobe_home=kobe.loc[kobe['X']!='@']
kobe_home
# Out:
#        G       Date   Tm    X  Opp Result  GS     MP    FG   FGA  ...  TRB  \
# 0      1 1996-11-03  LAL  NaN  MIN      W   0   6:00   0.0   1.0  ...    1
# 4      5 1996-11-10  LAL  NaN  ATL      W   0   8:00   0.0   3.0  ...    3
# 7      8 1996-11-15  LAL  NaN  LAC      W   0   7:00   1.0   4.0  ...    0
# 10    11 1996-11-20  LAL  NaN  UTA      L   0  21:00   4.0   5.0  ...    1
# 14    15 1996-12-01  LAL  NaN  DEN      W   0   3:00   1.0   2.0  ...    1
# ...   ..        ...  ...  ...  ...    ...  ..    ...   ...   ...  ...  ...
# 1555   2 2012-05-01  LAL  NaN  DEN      W   1  39:37  15.0  29.0  ...    4
# 1558   5 2012-05-08  LAL  NaN  DEN      L   1  43:12  14.0  32.0  ...    6
# 1560   7 2012-05-12  LAL  NaN  DEN      W   1  45:08   7.0  16.0  ...    1
# 1563  10 2012-05-18  LAL  NaN  OKC      W   1  38:58   9.0  25.0  ...    7
# 1564  11 2012-05-19  LAL  NaN  OKC      L   1  39:46  12.0  28.0  ...    8
#
#       AST  STL  BLK  TOV  PF   PTS  GmSc       Player          RSorPO
# 0       0  0.0  1.0    1   1   0.0  -1.1  Kobe Bryant  Regular Season
# 4       1  0.0  0.0    0   0   2.0   1.9  Kobe Bryant  Regular Season
# 7       0  0.0  0.0    1   4   4.0  -1.4  Kobe Bryant  Regular Season
# 10      1  0.0  1.0    2   1  11.0   8.4  Kobe Bryant  Regular Season
# 14      0  0.0  0.0    1   0   2.0   0.3  Kobe Bryant  Regular Season
# ...   ...  ...  ...  ...  ..   ...   ...          ...             ...
# 1555    2  3.0  1.0    1   3  38.0  28.2  Kobe Bryant        Playoffs
# 1558    5  2.0  0.0    3   2  43.0  29.7  Kobe Bryant        Playoffs
# 1560    8  0.0  1.0    3   2  17.0  10.6  Kobe Bryant        Playoffs
# 1563    6  2.0  0.0    2   4  36.0  27.6  Kobe Bryant        Playoffs
# 1564    5  0.0  0.0    2   1  38.0  26.7  Kobe Bryant        Playoffs
#
# [781 rows x 29 columns]

# %%
a4_dims = (12, 10)
fig, ax = plt.subplots(figsize=a4_dims)

kobe_home['Date'] = pd.to_datetime(kobe_home['Date'])
sns.boxplot(kobe_home['Date'].dt.year, kobe_home['PTS'], color='green').set_title('Kobe')
# Out:
# <ipython-input-44-f210068cbb47>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kobe_home['Date'] = pd.to_datetime(kobe_home['Date'])
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Kobe')

# %%
fig = plt.figure(constrained_layout=True, figsize=[11, 8])
ax = fig.add_subplot()

opponents = kobe_home["Opp"].unique()
wins, loses = list(), list()
for opponent in opponents:
    mapped = kobe_home[kobe_home["Opp"] == opponent]["Result"].map({"W":1, "L":0})
    wins.append(mapped.sum())
    loses.append(len(mapped) - mapped.sum())

widths = np.array(wins) - np.array(loses)
colors = ["red" if width < 0 else "green" for width in widths]

ax.hlines(y=opponents, xmin=0, xmax=widths, color=colors , alpha=0.8)
ax.hlines(y=opponents, xmin=-20, xmax=np.minimum(widths, 0)-0.5, alpha=0.2, linestyles="--")
ax.vlines(x=0, ymin=-1, ymax=len(opponents), alpha=0.3, linestyles="--")
ax.scatter(y=opponents, x=widths, color=colors)

for i in range(len(opponents)):
    ax.text(y=opponents[i], x=widths[i] + (1 if widths[i] > 0 else -1), s=widths[i], fontsize=12, color=colors[i], horizontalalignment="center", verticalalignment="center")

ax.set_title('Kobe - Home')
ax.set_yticklabels(opponents, fontsize=13)

plt.show()
# Out:
# <ipython-input-45-3e09e0b04575>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(opponents, fontsize=13)

# %%
kobe_away=kobe.loc[kobe['X']=='@']
kobe_away
# Out:
#        G       Date   Tm  X  Opp Result  GS     MP    FG   FGA  ...  TRB  AST  \
# 1      2 1996-11-05  LAL  @  NYK      W   0   3:00   0.0   1.0  ...    0    0
# 2      3 1996-11-06  LAL  @  CHH      L   0   7:00   2.0   3.0  ...    0    0
# 3      4 1996-11-08  LAL  @  TOR      L   0  17:00   3.0   8.0  ...    3    0
# 5      6 1996-11-12  LAL  @  HOU      W   0   5:00   1.0   2.0  ...    1    0
# 6      7 1996-11-13  LAL  @  SAS      L   0   6:00   2.0   2.0  ...    0    0
# ...   ..        ...  ... ..  ...    ...  ..    ...   ...   ...  ...  ...  ...
# 1557   4 2012-05-06  LAL  @  DEN      W   1  38:41  10.0  25.0  ...    8    6
# 1559   6 2012-05-10  LAL  @  DEN      L   1  37:03  13.0  23.0  ...    2    4
# 1561   8 2012-05-14  LAL  @  OKC      L   1  31:55   7.0  18.0  ...    3    2
# 1562   9 2012-05-16  LAL  @  OKC      L   1  42:46   9.0  25.0  ...    3    4
# 1565  12 2012-05-21  LAL  @  OKC      L   1  40:34  18.0  33.0  ...    5    0
#
#       STL  BLK  TOV  PF   PTS  GmSc       Player          RSorPO
# 1     0.0  0.0    1   0   1.0  -1.1  Kobe Bryant  Regular Season
# 2     0.0  0.0    3   0   5.0   0.7  Kobe Bryant  Regular Season
# 3     0.0  1.0    0   3  10.0   5.2  Kobe Bryant  Regular Season
# 5     0.0  0.0    2   0   2.0  -0.7  Kobe Bryant  Regular Season
# 6     1.0  0.0    0   2   6.0   5.6  Kobe Bryant  Regular Season
# ...   ...  ...  ...  ..   ...   ...          ...             ...
# 1557  1.0  0.0    5   0  22.0  11.5  Kobe Bryant        Playoffs
# 1559  1.0  0.0    3   3  31.0  20.3  Kobe Bryant        Playoffs
# 1561  0.0  0.0    3   3  20.0   7.5  Kobe Bryant        Playoffs
# 1562  4.0  0.0    2   4  20.0  10.6  Kobe Bryant        Playoffs
# 1565  2.0  0.0    2   3  42.0  25.6  Kobe Bryant        Playoffs
#
# [785 rows x 29 columns]

# %%
a4_dims = (12, 10)
fig, ax = plt.subplots(figsize=a4_dims)

kobe_away['Date'] = pd.to_datetime(kobe_away['Date'])
sns.boxplot(kobe_away['Date'].dt.year, kobe_away['PTS'], color='green').set_title('Kobe')
# Out:
# <ipython-input-47-29a87e58276a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kobe_away['Date'] = pd.to_datetime(kobe_away['Date'])
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Kobe')

# %%
fig = plt.figure(constrained_layout=True, figsize=[11, 8])
ax = fig.add_subplot()

opponents = kobe_away["Opp"].unique()
wins, loses = list(), list()
for opponent in opponents:
    mapped = kobe_away[kobe_away["Opp"] == opponent]["Result"].map({"W":1, "L":0})
    wins.append(mapped.sum())
    loses.append(len(mapped) - mapped.sum())

widths = np.array(wins) - np.array(loses)
colors = ["red" if width < 0 else "green" for width in widths]

ax.hlines(y=opponents, xmin=0, xmax=widths, color=colors , alpha=0.8)
ax.hlines(y=opponents, xmin=-20, xmax=np.minimum(widths, 0)-0.5, alpha=0.2, linestyles="--")
ax.vlines(x=0, ymin=-1, ymax=len(opponents), alpha=0.3, linestyles="--")
ax.scatter(y=opponents, x=widths, color=colors)

for i in range(len(opponents)):
    ax.text(y=opponents[i], x=widths[i] + (1 if widths[i] > 0 else -1), s=widths[i], fontsize=12, color=colors[i], horizontalalignment="center", verticalalignment="center")

ax.set_title('Kobe - Away')
ax.set_yticklabels(opponents, fontsize=13)

plt.show()
# Out:
# <ipython-input-48-25d6726efc49>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(opponents, fontsize=13)

# %%
lebron = all_games_stats.loc[all_games_stats['Player']== 'Lebron James']
lebron
# Out:
#        G        Date   Tm    X  Opp Result  GS     MP    FG   FGA  ...  TRB  \
# 1566   1  2003-10-29  CLE    @  SAC      L   1  42:00  12.0  20.0  ...    6
# 1567   2  2003-10-30  CLE    @  PHO      L   1  41:00   8.0  17.0  ...   12
# 1568   3  2003-11-01  CLE    @  POR      L   1  39:00   3.0  12.0  ...    4
# 1569   4  2003-11-05  CLE  NaN  DEN      L   1  41:00   3.0  11.0  ...   11
# 1570   5  2003-11-07  CLE    @  IND      L   1  44:00   8.0  18.0  ...    5
# ...   ..         ...  ...  ...  ...    ...  ..    ...   ...   ...  ...  ...
# 2998  18  2018-05-27  CLE    @  BOS      W   1  48:00  12.0  24.0  ...   15
# 2999  19  2018-05-31  CLE    @  GSW      L   1  47:32  19.0  32.0  ...    8
# 3000  20  2018-06-03  CLE    @  GSW      L   1  43:51  10.0  20.0  ...    9
# 3001  21  2018-06-06  CLE  NaN  GSW      L   1  46:52  13.0  28.0  ...   10
# 3002  22  2018-06-08  CLE  NaN  GSW      L   1  40:34   7.0  13.0  ...    7
#
#       AST  STL  BLK  TOV  PF   PTS  GmSc        Player          RSorPO
# 1566    9  4.0  0.0    2   3  25.0  24.7  Lebron James  Regular Season
# 1567    8  1.0  0.0    7   1  21.0  14.7  Lebron James  Regular Season
# 1568    6  2.0  0.0    2   3   8.0   5.0  Lebron James  Regular Season
# 1569    7  2.0  3.0    2   1   7.0  11.2  Lebron James  Regular Season
# 1570    3  0.0  0.0    7   2  23.0   9.0  Lebron James  Regular Season
# ...   ...  ...  ...  ...  ..   ...   ...           ...             ...
# 2998    9  0.0  2.0    8   4  35.0  24.4  Lebron James        Playoffs
# 2999    8  1.0  1.0    5   2  51.0   NaN  Lebron James        Playoffs
# 3000   13  2.0  0.0    5   2  29.0  26.6  Lebron James        Playoffs
# 3001   11  2.0  2.0    4   2  33.0  28.7  Lebron James        Playoffs
# 3002    8  0.0  1.0    6   5  23.0  16.7  Lebron James        Playoffs
#
# [1437 rows x 29 columns]

# %%
print(f"nMin: {lebron['PTS'].min()} \nMax: {lebron['PTS'].max()} \nAvg: {round(lebron['PTS'].mean())}")
# Out:
# nMin: 3.0
# Max: 61.0
# Avg: 27

# %%
print(f"nMin: {lebron['AST'].min()} \nMax: {lebron['AST'].max()} \nAvg: {round(lebron['AST'].mean())}")
# Out:
# nMin: 0
# Max: 19
# Avg: 7

# %%
print(f"nMin: {lebron['TRB'].min()} \nMax: {lebron['TRB'].max()} \nAvg: {round(lebron['TRB'].mean())}")
# Out:
# nMin: 0
# Max: 19
# Avg: 8

# %%
print(f"nMin: {lebron['FG'].min()} \nMax: {lebron['FG'].max()} \nAvg: {round(lebron['FG'].mean())}")
# Out:
# nMin: 0.0
# Max: 23.0
# Avg: 10

# %%
a4_dims = (12, 10)
fig, ax = plt.subplots(figsize= a4_dims)

lebron['Date'] = pd.to_datetime(lebron['Date'])
sns.boxplot(lebron['Date'].dt.year, lebron['PTS'], color='yellow').set_title('Lebron')
# Out:
# <ipython-input-54-25dbc52fff8a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lebron['Date'] = pd.to_datetime(lebron['Date'])
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Lebron')

# %%
fig = plt.figure(constrained_layout=True, figsize=[11, 8])
ax = fig.add_subplot()

opponents = lebron["Opp"].unique()
wins, loses = list(), list()
for opponent in opponents:
    mapped = lebron[lebron["Opp"] == opponent]["Result"].map({"W":1, "L":0})
    wins.append(mapped.sum())
    loses.append(len(mapped) - mapped.sum())

widths = np.array(wins) - np.array(loses)
colors = ["red" if width < 0 else "green" for width in widths]

ax.hlines(y=opponents, xmin=0, xmax=widths, color=colors , alpha=0.8)
ax.hlines(y=opponents, xmin=-20, xmax=np.minimum(widths, 0)-0.5, alpha=0.2, linestyles="--")
ax.vlines(x=0, ymin=-1, ymax=len(opponents), alpha=0.3, linestyles="--")
ax.scatter(y=opponents, x=widths, color=colors)

for i in range(len(opponents)):
    ax.text(y=opponents[i], x=widths[i] + (1 if widths[i] > 0 else -1), s=widths[i], fontsize=12, color=colors[i], horizontalalignment="center", verticalalignment="center")

ax.set_title('Lebron - Games')
ax.set_yticklabels(opponents, fontsize=13)

plt.show()
# Out:
# <ipython-input-55-a4f3fe07a5dc>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(opponents, fontsize=13)

# %%
lebron_home=lebron.loc[lebron['X']!='@']
lebron_home
# Out:
#        G       Date   Tm    X  Opp Result  GS     MP    FG   FGA  ...  TRB  \
# 1569   4 2003-11-05  CLE  NaN  DEN      L   1  41:00   3.0  11.0  ...   11
# 1571   6 2003-11-08  CLE  NaN  WAS      W   1  45:00   8.0  19.0  ...    8
# 1572   7 2003-11-10  CLE  NaN  NYK      W   1  34:00   7.0  12.0  ...    5
# 1575  10 2003-11-15  CLE  NaN  PHI      W   1  47:00  10.0  19.0  ...    5
# 1576  11 2003-11-18  CLE  NaN  LAC      W   1  39:00   6.0  16.0  ...    7
# ...   ..        ...  ...  ...  ...    ...  ..    ...   ...   ...  ...  ...
# 2994  14 2018-05-19  CLE  NaN  BOS      W   1  37:30   8.0  12.0  ...    5
# 2995  15 2018-05-21  CLE  NaN  BOS      W   1  41:53  17.0  28.0  ...    5
# 2997  17 2018-05-25  CLE  NaN  BOS      W   1  46:06  17.0  33.0  ...   11
# 3001  21 2018-06-06  CLE  NaN  GSW      L   1  46:52  13.0  28.0  ...   10
# 3002  22 2018-06-08  CLE  NaN  GSW      L   1  40:34   7.0  13.0  ...    7
#
#       AST  STL  BLK  TOV  PF   PTS  GmSc        Player          RSorPO
# 1569    7  2.0  3.0    2   1   7.0  11.2  Lebron James  Regular Season
# 1571    9  1.0  1.0    2   1  17.0  15.7  Lebron James  Regular Season
# 1572    4  1.0  1.0    2   0  17.0  15.8  Lebron James  Regular Season
# 1575    8  1.0  2.0    5   2  22.0  15.6  Lebron James  Regular Season
# 1576    8  0.0  1.0    3   2  14.0   9.8  Lebron James  Regular Season
# ...   ...  ...  ...  ...  ..   ...   ...           ...             ...
# 2994   12  2.0  2.0    3   3  27.0  30.5  Lebron James        Playoffs
# 2995    3  2.0  0.0    7   3  44.0  27.4  Lebron James        Playoffs
# 2997    9  3.0  1.0    3   2  46.0   NaN  Lebron James        Playoffs
# 3001   11  2.0  2.0    4   2  33.0  28.7  Lebron James        Playoffs
# 3002    8  0.0  1.0    6   5  23.0  16.7  Lebron James        Playoffs
#
# [726 rows x 29 columns]

# %%
a4_dims = (12, 10)
fig, ax = plt.subplots(figsize=a4_dims)

lebron_home['Date'] = pd.to_datetime(lebron_home['Date'])
sns.boxplot(lebron_home['Date'].dt.year, lebron_home['PTS'], color='yellow').set_title('Lebron - Home')
# Out:
# <ipython-input-57-d321625019f5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lebron_home['Date'] = pd.to_datetime(lebron_home['Date'])
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Lebron - Home')

# %%
fig = plt.figure(constrained_layout=True, figsize=[11, 8])
ax = fig.add_subplot()

opponents = lebron_home["Opp"].unique()
wins, loses = list(), list()
for opponent in opponents:
    mapped = lebron_home[lebron_home["Opp"] == opponent]["Result"].map({"W":1, "L":0})
    wins.append(mapped.sum())
    loses.append(len(mapped) - mapped.sum())

widths = np.array(wins) - np.array(loses)
colors = ["red" if width < 0 else "green" for width in widths]

ax.hlines(y=opponents, xmin=0, xmax=widths, color=colors , alpha=0.8)
ax.hlines(y=opponents, xmin=-20, xmax=np.minimum(widths, 0)-0.5, alpha=0.2, linestyles="--")
ax.vlines(x=0, ymin=-1, ymax=len(opponents), alpha=0.3, linestyles="--")
ax.scatter(y=opponents, x=widths, color=colors)

for i in range(len(opponents)):
    ax.text(y=opponents[i], x=widths[i] + (1 if widths[i] > 0 else -1), s=widths[i], fontsize=12, color=colors[i], horizontalalignment="center", verticalalignment="center")

ax.set_title('Lebron - Home')
ax.set_yticklabels(opponents, fontsize=13)

plt.show()
# Out:
# <ipython-input-58-2961a37d0c49>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(opponents, fontsize=13)

# %%
lebron_away=lebron.loc[lebron['X']=='@']
lebron_away
# Out:
#        G       Date   Tm  X  Opp Result  GS     MP    FG   FGA  ...  TRB  AST  \
# 1566   1 2003-10-29  CLE  @  SAC      L   1  42:00  12.0  20.0  ...    6    9
# 1567   2 2003-10-30  CLE  @  PHO      L   1  41:00   8.0  17.0  ...   12    8
# 1568   3 2003-11-01  CLE  @  POR      L   1  39:00   3.0  12.0  ...    4    6
# 1570   5 2003-11-07  CLE  @  IND      L   1  44:00   8.0  18.0  ...    5    3
# 1573   8 2003-11-12  CLE  @  MIA      L   1  42:00   6.0  15.0  ...    3    7
# ...   ..        ...  ... ..  ...    ...  ..    ...   ...   ...  ...  ...  ...
# 2993  13 2018-05-15  CLE  @  BOS      L   1  38:46  16.0  29.0  ...   10   12
# 2996  16 2018-05-23  CLE  @  BOS      L   1  39:16  11.0  22.0  ...   10    5
# 2998  18 2018-05-27  CLE  @  BOS      W   1  48:00  12.0  24.0  ...   15    9
# 2999  19 2018-05-31  CLE  @  GSW      L   1  47:32  19.0  32.0  ...    8    8
# 3000  20 2018-06-03  CLE  @  GSW      L   1  43:51  10.0  20.0  ...    9   13
#
#       STL  BLK  TOV  PF   PTS  GmSc        Player          RSorPO
# 1566  4.0  0.0    2   3  25.0  24.7  Lebron James  Regular Season
# 1567  1.0  0.0    7   1  21.0  14.7  Lebron James  Regular Season
# 1568  2.0  0.0    2   3   8.0   5.0  Lebron James  Regular Season
# 1570  0.0  0.0    7   2  23.0   9.0  Lebron James  Regular Season
# 1573  2.0  1.0    4   3  18.0  12.8  Lebron James  Regular Season
# ...   ...  ...  ...  ..   ...   ...           ...             ...
# 2993  0.0  1.0    6   3  42.0  31.4  Lebron James        Playoffs
# 2996  1.0  0.0    6   2  26.0  15.3  Lebron James        Playoffs
# 2998  0.0  2.0    8   4  35.0  24.4  Lebron James        Playoffs
# 2999  1.0  1.0    5   2  51.0   NaN  Lebron James        Playoffs
# 3000  2.0  0.0    5   2  29.0  26.6  Lebron James        Playoffs
#
# [711 rows x 29 columns]

# %%
a4_dims = (12, 10)
fig, ax = plt.subplots(figsize=a4_dims)

lebron_away['Date'] = pd.to_datetime(lebron_away['Date'])
sns.boxplot(lebron_away['Date'].dt.year, lebron_away['PTS'], color='yellow').set_title('Lebron - Away')
# Out:
# <ipython-input-60-6791514e14de>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lebron_away['Date'] = pd.to_datetime(lebron_away['Date'])
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Lebron - Away')

# %%
fig = plt.figure(constrained_layout=True, figsize=[11, 8])
ax = fig.add_subplot()

opponents = lebron_away["Opp"].unique()
wins, loses = list(), list()
for opponent in opponents:
    mapped = lebron_away[lebron_away["Opp"] == opponent]["Result"].map({"W":1, "L":0})
    wins.append(mapped.sum())
    loses.append(len(mapped) - mapped.sum())

widths = np.array(wins) - np.array(loses)
colors = ["red" if width < 0 else "green" for width in widths]

ax.hlines(y=opponents, xmin=0, xmax=widths, color=colors , alpha=0.8)
ax.hlines(y=opponents, xmin=-20, xmax=np.minimum(widths, 0)-0.5, alpha=0.2, linestyles="--")
ax.vlines(x=0, ymin=-1, ymax=len(opponents), alpha=0.3, linestyles="--")
ax.scatter(y=opponents, x=widths, color=colors)

for i in range(len(opponents)):
    ax.text(y=opponents[i], x=widths[i] + (1 if widths[i] > 0 else -1), s=widths[i], fontsize=12, color=colors[i], horizontalalignment="center", verticalalignment="center")

ax.set_title('Lebron - Away')
ax.set_yticklabels(opponents, fontsize=13)

plt.show()
# Out:
# <ipython-input-61-88575334682d>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(opponents, fontsize=13)
