# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
game_high=pd.read_csv(r'C:\Users\broken\Desktop\BootCamp Data Science\Proyecto EDA\Proyecto-NBA-EDA-DS\data\game_highs_stats.csv')
game_high
# Out:
#      Season  Age   Tm   Lg     MP  FG  FGA  3P  3PA  2P  ...  TRB  AST  STL  \
# 0   2003-04   19  CLE  NBA    NaN  15   29   5   10  15  ...   16   13    6
# 1   2004-05   20  CLE  NBA    NaN  18   36   7   13  15  ...   18   15    7
# 2   2005-06   21  CLE  NBA  53:55  19   35   6   11  18  ...   13   12    6
# 3   2006-07   22  CLE  NBA  53:10  17   31   4    9  16  ...   17   12    4
# 4   2007-08   23  CLE  NBA  50:13  18   32   7   13  16  ...   19   14    6
# ..      ...  ...  ...  ...    ...  ..  ...  ..  ...  ..  ...  ...  ...  ...
# 87  2007-08   29  LAL  NBA  46:32  18   33   5   10  14  ...   10   10    5
# 88  2008-09   30  LAL  NBA  48:52  16   34   4   10  16  ...    8   10    4
# 89  2009-10   31  LAL  NBA  44:51  15   29   6   11  12  ...   15   13    4
# 90  2010-11   32  LAL  NBA  42:05  14   29   4    9  12  ...    6    8    5
# 91  2011-12   33  LAL  NBA  45:08  18   33   5   11  17  ...    8    8    4
#
# ...

# %%
print("DataFrame shape: ",game_high.shape)
print("DataFrame info: ",game_high.info())
print("DataFrame columns: ",game_high.columns)
print("how many missing in every column: ",game_high.isna().sum())
print("type of each column: ",game_high.dtypes)
print("numerical column stat: ", game_high.describe().T)
# Out:
# DataFrame shape:  (92, 25)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  92 non-null     object
#  1   Age     92 non-null     int64
#  2   Tm      92 non-null     object
#  3   Lg      92 non-null     object
#  4   MP      45 non-null     object
#  5   FG      92 non-null     int64
#  6   FGA     92 non-null     int64
#  7   3P      92 non-null     int64
#  8   3PA     92 non-null     int64
#  9   2P      92 non-null     int64
#  10  2PA     92 non-null     int64
#  11  FT      92 non-null     int64
#  12  FTA     92 non-null     int64
#  13  ORB     92 non-null     int64
#  14  DRB     92 non-null     int64
#  15  TRB     92 non-null     int64
#  16  AST     92 non-null     int64
#  17  STL     92 non-null     int64
#  18  BLK     92 non-null     int64
#  19  TOV     92 non-null     int64
#  20  PF      92 non-null     int64
# ...

# %%
regular = game_high.loc [game_high['RSorPO']=='Regular Season']
regular
# Out:
#      Season  Age   Tm   Lg     MP  FG  FGA  3P  3PA  2P  ...  TRB  AST  STL  \
# 0   2003-04   19  CLE  NBA    NaN  15   29   5   10  15  ...   16   13    6
# 1   2004-05   20  CLE  NBA    NaN  18   36   7   13  15  ...   18   15    7
# 2   2005-06   21  CLE  NBA  53:55  19   35   6   11  18  ...   13   12    6
# 3   2006-07   22  CLE  NBA  53:10  17   31   4    9  16  ...   17   12    4
# 4   2007-08   23  CLE  NBA  50:13  18   32   7   13  16  ...   19   14    6
# 5   2008-09   24  CLE  NBA  46:59  17   33   8   11  15  ...   15   14    5
# 6   2009-10   25  CLE  NBA  47:00  17   33   6   12  14  ...   16   15    5
# 7   2010-11   26  MIA  NBA  46:44  17   30   5   10  14  ...   13   14    6
# 8   2011-12   27  MIA  NBA  47:18  16   27   4    7  16  ...   13   13    5
# 9   2012-13   28  MIA  NBA  51:56  17   31   7   10  16  ...   16   16    6
# 10  2013-14   29  MIA  NBA  49:22  22   33   8   10  14  ...   14   13    6
# ...

# %%
def compare_FG():
    subset = regular.loc[:, ['Player','FG']].groupby('Player').describe()
    return subset

compare_FG()
# Out:
#                   FG
#                count       mean       std   min   25%   50%    75%   max
# Player
# Kobe Bryant     20.0  17.450000  4.593760   9.0  15.0  17.0  20.25  28.0
# Lebron James    16.0  17.750000  2.175623  15.0  17.0  17.0  18.25  23.0
# Michael Jordan  15.0  20.466667  3.181793  13.0  18.5  21.0  21.50  27.0

# %%
def compare_3P():
    subset = regular.loc[:, ['Player','3P']].groupby('Player').describe()
    return subset

compare_3P()
# Out:
#                   3P
#                count      mean       std  min  25%  50%  75%   max
# Player
# Kobe Bryant     20.0  5.500000  2.502630  2.0  4.0  5.0  7.0  12.0
# Lebron James    16.0  5.875000  1.310216  4.0  5.0  6.0  7.0   8.0
# Michael Jordan  15.0  3.333333  1.759329  1.0  2.0  3.0  4.5   7.0

# %%
def compare_2P():
    subset = regular.loc[:, ['Player','2P']].groupby('Player').describe()
    return subset

compare_2P()
# Out:
#                   2P
#                count       mean       std   min   25%   50%   75%   max
# Player
# Kobe Bryant     20.0  15.000000  3.825125   7.0  13.0  15.5  18.0  21.0
# Lebron James    16.0  15.375000  1.927866  13.0  14.0  15.0  16.0  21.0
# Michael Jordan  15.0  19.733333  3.150208  13.0  18.0  20.0  21.0  26.0

# %%
def compare_PTs():
    subset = regular.loc[:, ['Player','PTS']].groupby('Player').describe()
    return subset

compare_PTs()
# Out:
#                  PTS
#                count  mean        std   min   25%   50%    75%   max
# Player
# Kobe Bryant     20.0  47.8  13.782521  21.0  41.5  47.5  55.25  81.0
# Lebron James    16.0  48.0   7.257180  37.0  41.0  49.5  52.75  61.0
# Michael Jordan  15.0  52.6   8.600664  33.0  49.0  51.0  57.00  69.0

# %%
playoff=game_high.loc [game_high['RSorPO']=='Playoffs']
playoff
# Out:
#      Season  Age   Tm   Lg     MP  FG  FGA  3P  3PA  2P  ...  TRB  AST  STL  \
# 16  2005-06   21  CLE  NBA  53:00  16   30   7   12  14  ...   14   11    4
# 17  2006-07   22  CLE  NBA  50:18  18   33   3    7  16  ...   14   12    4
# 18  2007-08   23  CLE  NBA  46:48  14   29   3   11  12  ...   13   13    4
# 19  2008-09   24  CLE  NBA  49:24  20   30   5   10  17  ...   14   12    4
# 20  2009-10   25  CLE  NBA  46:12  16   26   6    9  14  ...   19   11    3
# 21  2010-11   26  MIA  NBA  50:17  14   28   5    7  12  ...   15   10    4
# 22  2011-12   27  MIA  NBA  48:06  19   27   2    6  17  ...   18   13    6
# 23  2012-13   28  MIA  NBA  49:46  15   26   5   10  14  ...   18   11    4
# 24  2013-14   29  MIA  NBA  43:36  16   24   4    9  13  ...   10    9    5
# 25  2014-15   30  CLE  NBA  50:20  18   38   3   10  16  ...   18   14    4
# 26  2015-16   31  CLE  NBA  46:49  16   30   4    8  13  ...   16   11    5
# ...

# %%
def compare_FG():
    subset = playoff.loc[:, ['Player','FG']].groupby('Player').describe()
    return subset

compare_FG()
# Out:
#                   FG
#                count       mean       std   min   25%   50%   75%   max
# Player
# Kobe Bryant     15.0  14.866667  3.502380   7.0  14.0  15.0  17.0  20.0
# Lebron James    13.0  16.923077  2.019139  14.0  16.0  16.0  19.0  20.0
# Michael Jordan  13.0  18.846154  3.436232  12.0  17.0  20.0  21.0  24.0

# %%
def compare_3P():
    subset = playoff.loc[:, ['Player','3P']].groupby('Player').describe()
    return subset

compare_3P()
# Out:
#                   3P
#                count      mean       std  min  25%  50%  75%  max
# Player
# Kobe Bryant     15.0  4.000000  1.463850  1.0  3.5  4.0  5.0  6.0
# Lebron James    13.0  4.461538  1.450022  2.0  3.0  5.0  5.0  7.0
# Michael Jordan  13.0  3.000000  1.683251  1.0  2.0  3.0  4.0  6.0

# %%
def compare_2P():
    subset = playoff.loc[:, ['Player','2P']].groupby('Player').describe()
    return subset

compare_2P()
# Out:
#                   2P
#                count       mean       std   min   25%   50%   75%   max
# Player
# Kobe Bryant     15.0  13.200000  3.363671   5.0  12.0  14.0  15.0  18.0
# Lebron James    13.0  14.846154  2.075498  12.0  13.0  14.0  17.0  18.0
# Michael Jordan  13.0  18.230769  3.767268  12.0  16.0  19.0  21.0  24.0

# %%
def compare_PTs():
    subset = playoff.loc[:, ['Player','PTS']].groupby('Player').describe()
    return subset

compare_PTs()
# Out:
#                  PTS
#                count       mean       std   min   25%   50%   75%   max
# Player
# Kobe Bryant     15.0  38.400000  8.846307  22.0  35.5  40.0  44.0  50.0
# Lebron James    13.0  43.846154  4.845034  35.0  41.0  45.0  48.0  51.0
# Michael Jordan  13.0  49.615385  7.240378  35.0  46.0  49.0  55.0  63.0
