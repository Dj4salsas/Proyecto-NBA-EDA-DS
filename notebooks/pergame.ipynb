# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
per_game=pd.read_csv(r'C:\Users\broken\Desktop\BootCamp Data Science\Proyecto EDA\Proyecto-NBA-EDA-DS\data\per_game_stats.csv')
per_game
# Out:
#      Season  Age   Tm   Lg Pos   G  GS    MP    FG   FGA  ...  DRB  TRB  AST  \
# 0   2003-04   19  CLE  NBA  SG  79  79  39.5   7.9  18.9  ...  4.2  5.5  5.9
# 1   2004-05   20  CLE  NBA  SF  80  80  42.4   9.9  21.1  ...  6.0  7.4  7.2
# 2   2005-06   21  CLE  NBA  SF  79  79  42.5  11.1  23.1  ...  6.1  7.0  6.6
# 3   2006-07   22  CLE  NBA  SF  78  78  40.9   9.9  20.8  ...  5.7  6.7  6.0
# 4   2007-08   23  CLE  NBA  SF  75  74  40.4  10.6  21.9  ...  6.1  7.9  7.2
# ..      ...  ...  ...  ...  ..  ..  ..   ...   ...   ...  ...  ...  ...  ...
# 87  2007-08   29  LAL  NBA  SG  21  21  41.1  10.6  22.0  ...  4.8  5.7  5.6
# 88  2008-09   30  LAL  NBA  SG  23  23  40.9  10.5  23.0  ...  4.5  5.3  5.5
# 89  2009-10   31  LAL  NBA  SG  23  23  40.1  10.2  22.2  ...  4.9  6.0  5.5
# 90  2010-11   32  LAL  NBA  SG  10  10  35.4   8.3  18.6  ...  2.6  3.4  3.3
# 91  2011-12   33  LAL  NBA  SG  12  12  39.7  11.0  25.1  ...  3.5  4.8  4.3
#
# ...

# %%
print("DataFrame shape: ",per_game.shape)
print("DataFrame info: ",per_game.info())
print("DataFrame columns: ",per_game.columns)
print("how many missing in every column: ",per_game.isna().sum())
print("type of each column: ",per_game.dtypes)
print("numerical column stat: ", per_game.describe().T)
# Out:
# DataFrame shape:  (92, 32)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 32 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  92 non-null     object
#  1   Age     92 non-null     int64
#  2   Tm      92 non-null     object
#  3   Lg      92 non-null     object
#  4   Pos     92 non-null     object
#  5   G       92 non-null     int64
#  6   GS      92 non-null     int64
#  7   MP      92 non-null     float64
#  8   FG      92 non-null     float64
#  9   FGA     92 non-null     float64
#  10  FG%     92 non-null     float64
#  11  3P      92 non-null     float64
#  12  3PA     92 non-null     float64
#  13  3P%     92 non-null     float64
#  14  2P      92 non-null     float64
#  15  2PA     92 non-null     float64
#  16  2P%     92 non-null     float64
#  17  eFG%    92 non-null     float64
#  18  FT      92 non-null     float64
#  19  FTA     92 non-null     float64
# ...

# %%
def compare_MP():
    subset = per_game.loc[:, ['Player','MP']].groupby('Player').describe()
    return subset

compare_MP()
# Out:
#                   MP
#                count       mean       std   min     25%   50%     75%   max
# Player
# Kobe Bryant     35.0  36.840000  7.596601  14.8  35.750  38.9  40.950  44.9
# Lebron James    29.0  40.131034  2.827430  35.2  37.800  40.4  42.200  46.5
# Michael Jordan  28.0  39.685714  3.623658  25.1  38.675  40.3  42.025  45.0

# %%
def compare_FG():
    subset = per_game.loc[:, ['Player','FG']].groupby('Player').describe()
    return subset

compare_FG()
# Out:
#                   FG
#                count       mean       std  min     25%    50%     75%   max
# Player
# Kobe Bryant     35.0   8.651429  2.553241  2.3   7.750   9.50  10.400  12.2
# Lebron James    29.0  10.058621  1.084803  7.9   9.600  10.00  10.600  12.5
# Michael Jordan  28.0  11.632143  1.791762  8.3  10.625  11.75  12.775  16.0

# %%
def compare_3P():
    subset = per_game.loc[:, ['Player','3P']].groupby('Player').describe()
    return subset

compare_3P()
# Out:
#                   3P
#                count      mean       std  min    25%  50%   75%  max
# Player
# Kobe Bryant     35.0  1.311429  0.550813  0.3  0.900  1.4  1.75  2.3
# Lebron James    29.0  1.510345  0.346765  0.8  1.300  1.5  1.70  2.4
# Michael Jordan  28.0  0.635714  0.454781  0.1  0.275  0.6  1.00  1.5

# %%
def compare_3Per():
    subset = per_game.loc[:, ['Player','3P%']].groupby('Player').describe()
    return subset

compare_3Per()
# Out:
#                  3P%
#                count      mean       std   min     25%    50%     75%   max
# Player
# Kobe Bryant     35.0  0.320286  0.049675  0.19  0.2850  0.330  0.3500  0.40
# Lebron James    29.0  0.341034  0.045067  0.24  0.3200  0.340  0.3700  0.42
# Michael Jordan  28.0  0.330714  0.162434  0.12  0.2275  0.325  0.3925  1.00

# %%
def compare_2P():
    subset = per_game.loc[:, ['Player','2P']].groupby('Player').describe()
    return subset

compare_2P()
# Out:
#                   2P
#                count       mean       std  min    25%    50%    75%   max
# Player
# Kobe Bryant     35.0   7.340000  2.251300  1.7  6.700   7.80   8.95  10.0
# Lebron James    29.0   8.558621  0.953384  6.9  7.900   8.60   9.10  10.7
# Michael Jordan  28.0  11.010714  1.781664  8.1  9.875  11.05  11.70  15.7

# %%
def compare_2Per():
    subset = per_game.loc[:, ['Player','2P%']].groupby('Player').describe()
    return subset

compare_2Per()
# Out:
#                  2P%
#                count      mean       std    min     25%    50%    75%    max
# Player
# Kobe Bryant     35.0  0.474429  0.028112  0.401  0.4590  0.483  0.490  0.532
# Lebron James    29.0  0.545345  0.052619  0.438  0.5130  0.549  0.582  0.625
# Michael Jordan  28.0  0.499214  0.040565  0.403  0.4755  0.503  0.533  0.553

# %%
def compare_BLK():
    subset = per_game.loc[:, ['Player','BLK']].groupby('Player').describe()
    return subset

compare_BLK()
# Out:
#                  BLK
#                count      mean       std  min    25%   50%    75%  max
# Player
# Kobe Bryant     35.0  0.522857  0.333507  0.1  0.300  0.40  0.750  1.5
# Lebron James    29.0  0.872414  0.312703  0.3  0.700  0.80  1.100  1.8
# Michael Jordan  28.0  0.932143  0.432952  0.3  0.675  0.85  1.125  2.3

# %%
def compare_PTS():
    subset = per_game.loc[:, ['Player','PTS']].groupby('Player').describe()
    return subset

compare_PTS()
# Out:
#                  PTS
#                count       mean       std   min     25%   50%    75%   max
# Player
# Kobe Bryant     35.0  24.497143  7.002205   7.6  21.700  26.8  29.30  35.4
# Lebron James    29.0  28.051724  3.036989  20.9  26.400  27.4  30.00  35.3
# Michael Jordan  28.0  31.596429  4.854588  20.0  29.525  31.5  34.85  43.7

# %%
def compare_AST():
    subset = per_game.loc[:, ['Player','AST']].groupby('Player').describe()
    return subset

compare_AST()
# Out:
#                  AST
#                count      mean       std  min   25%  50%    75%  max
# Player
# Kobe Bryant     35.0  4.628571  1.337595  1.2  4.40  5.0  5.500  6.3
# Lebron James    29.0  7.168966  1.090578  4.8  6.30  7.2  7.800  9.1
# Michael Jordan  28.0  5.482143  1.456290  2.9  4.45  5.5  6.025  8.5

# %%
def compare_STL():
    subset = per_game.loc[:, ['Player','STL']].groupby('Player').describe()
    return subset

compare_STL()
# Out:
#                  STL
#                count      mean       std  min  25%  50%    75%  max
# Player
# Kobe Bryant     35.0  1.371429  0.413430  0.3  1.2  1.4  1.650  2.2
# Lebron James    29.0  1.672414  0.238891  1.2  1.6  1.7  1.800  2.3
# Michael Jordan  28.0  2.246429  0.499987  1.4  1.8  2.3  2.725  3.2

# %%
def compare_ORB():
    subset = per_game.loc[:, ['Player','ORB']].groupby('Player').describe()
    return subset

compare_ORB()
# Out:
#                  ORB
#                count      mean       std  min    25%  50%  75%  max
# Player
# Kobe Bryant     35.0  1.025714  0.408255  0.1  0.800  1.1  1.3  1.8
# Lebron James    29.0  1.341379  0.371788  0.7  1.100  1.3  1.5  2.3
# Michael Jordan  28.0  1.635714  0.375366  0.8  1.475  1.7  1.8  2.3

# %%
def compare_DRB():
    subset = per_game.loc[:, ['Player','DRB']].groupby('Player').describe()
    return subset

compare_DRB()
# Out:
#                  DRB
#                count      mean       std  min    25%   50%    75%  max
# Player
# Kobe Bryant     35.0  4.054286  1.176321  1.1  3.850  4.30  4.750  5.7
# Lebron James    29.0  6.744828  1.003062  4.2  6.100  6.60  7.400  9.5
# Michael Jordan  28.0  4.646429  0.863448  2.3  4.425  4.75  5.225  6.2

# %%
def compare_TRB():
    subset = per_game.loc[:, ['Player','TRB']].groupby('Player').describe()
    return subset

compare_TRB()
# Out:
#                  TRB
#                count      mean       std  min   25%  50%   75%   max
# Player
# Kobe Bryant     35.0  5.088571  1.393002  1.2  4.75  5.4  5.85   7.3
# Lebron James    29.0  8.062069  1.183039  5.5  7.40  8.0  8.60  11.3
# Michael Jordan  28.0  6.282143  0.918958  3.6  5.80  6.4  6.90   8.0

# %%
MJ = per_game.loc[per_game['Player'] == 'Michael Jordan', ['PTS']]
LBJ = per_game.loc[per_game['Player'] == 'Lebron James', ['PTS']]
kobe = per_game.loc[per_game['Player'] == 'Kobe Bryant', ['PTS']]


plt.figure(figsize = (20,10))
sns.distplot(MJ, label='MJ')
sns.distplot(LBJ, label='LBJ')
sns.distplot(kobe, label='Kobe')
plt.title("Points")
plt.legend()
# Out:
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
MJ = per_game.loc[per_game['Player'] == 'Michael Jordan', ['AST']]
LBJ = per_game.loc[per_game['Player'] == 'Lebron James', ['AST']]
kobe = per_game.loc[per_game['Player'] == 'Kobe Bryant', ['AST']]


plt.figure(figsize = (20,10))
sns.distplot(MJ, label='MJ')
sns.distplot(LBJ, label='LBJ')
sns.distplot(kobe, label='Kobe')
plt.title("Total Assists")
plt.legend()
# Out:
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
MJ = per_game.loc[per_game['Player'] == 'Michael Jordan', ['TRB']]
LBJ = per_game.loc[per_game['Player'] == 'Lebron James', ['TRB']]
kobe = per_game.loc[per_game['Player'] == 'Kobe Bryant', ['TRB']]


plt.figure(figsize = (20,10))
sns.distplot(MJ, label='MJ')
sns.distplot(LBJ, label='LBJ')
sns.distplot(kobe, label='Kobe')
plt.title("Total Rebounds")
plt.legend()
# Out:
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
MJ = per_game.loc[per_game['Player'] == 'Michael Jordan', ['FG']]
LBJ = per_game.loc[per_game['Player'] == 'Lebron James', ['FG']]
kobe = per_game.loc[per_game['Player'] == 'Kobe Bryant', ['FG']]


plt.figure(figsize = (20,10))
sns.distplot(MJ, label='MJ')
sns.distplot(LBJ, label='LBJ')
sns.distplot(kobe, label='Kobe')
plt.title("Field Goals")
plt.legend()
# Out:
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\broken\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
